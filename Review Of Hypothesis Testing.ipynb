# %%
import random
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib inline

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.tools import FigureFactory as FF

# %%
random.gauss(10,10)
# Out:
# 9.977936249007696

# %%
data1 = np.random.normal(10,3, size=1000)
data2 = np.random.normal(10.5,3, size=1000)

# %%
stats.ttest_ind(data1, data2)
# Out:
# Ttest_indResult(statistic=-4.782380143576619, pvalue=1.8589557633928338e-06)

# %%
from scipy.optimize import curve_fit
def gaus(x,a,x0,sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

res = plt.hist(data1,bins=20)
y = res[0][0:20]
x = res[1][0:20]
mean = 10
sigma = 3

popt,pcov = curve_fit(gaus,x,y,p0=[1,mean,sigma])

plt.plot(x,y,'b+:',label='data')
plt.plot(x,gaus(x,*popt),'ro:',label='fit')

plt.legend()
plt.title('Distribution of scores')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.show()

# %%
res = plt.hist(data1,bins=20)
res
mu = 10
variance = 9
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, 850*stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
res = plt.hist(data2,bins=20)

# %%
mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
mu = 1
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
res = plt.hist(data1,bins=20)
y = res[0][0:20]
x = res[1][0:20]
plt.plot(x,y)
plt.show()
